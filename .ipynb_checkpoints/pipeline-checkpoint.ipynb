# %%
import numpy as np
import scipy as sc
import pandas as pd
import matplotlib as plt
import seaborn as sns
import os
# %matplotlib inline

# %%
from collections import OrderedDict
series = OrderedDict()
for filename in os.listdir("datasets/Stock Prices/"):
    path = "datasets/Stock Prices/" + filename
    col1 = str(filename.split(".")[0] + 'close')
    col2 = str(filename.split(".")[0] + 'volume')
    series[filename] = pd.read_csv(path, parse_dates=True, header=0, index_col=0, 
                                   usecols=['Date', 'Close', 'Volume'])
    series[filename] = series[filename].rename(columns={'Date':'date','Close':col1,'Volume':col2})
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-51-5c8980fab2a7> in <module>()
#       7     series[filename] = pd.read_csv(path, parse_dates=True, header=0, index_col=0,
#       8                                    usecols=['Date', 'Close', 'Volume'])
# ----> 9     series = series.rename(columns={'Date':'date','Close':col1,'Volume':col2})
#
# AttributeError: 'OrderedDict' object has no attribute 'rename'

# %%
df = pd.DataFrame()
for each in series.keys():
    df = pd.concat([df, series[each]], axis=1).dropna()
df.head()
# Out:
#              ABBclose  ABBvolume  ASYSclose  ASYSvolume  CCGIclose  \
# Date
# 2010-06-29  17.490000  4731000.0       8.27     47400.0       45.0
# 2010-06-30  17.280001  4224600.0       8.35     12800.0       42.5
# 2010-07-01  17.590000  6328900.0       8.71     70400.0       44.5
# 2010-07-02  17.430000  2315300.0       8.59     41200.0       45.0
# 2010-07-06  17.690001  2955000.0       8.60     30600.0       37.5
#
#             CCGIvolume  CENXclose  CENXvolume   CMIclose  CMIvolume  \
# Date
# 2010-06-29         0.0       9.07   4079400.0  66.239998  4498100.0
# 2010-06-30         0.0       8.83   3519600.0  65.129997  3268500.0
# 2010-07-01         0.0       8.68   3968000.0  64.820000  5136200.0
# 2010-07-02         0.0       8.60   2444000.0  64.239998  3766900.0
# 2010-07-06         0.0       8.61   3302200.0  63.570000  3913900.0
#
#              FSLRclose  FSLRvolume  GEclose     GEvolume  PCRFYclose  \
# Date
# 2010-06-29  114.419998   2243400.0    14.48  114904900.0       12.47
# 2010-06-30  113.830002   1937300.0    14.42   81568200.0       12.53
# 2010-07-01  117.449997   2078200.0    14.12  107077700.0       12.43
# 2010-07-02  120.519997   2082800.0    13.88   78544600.0       12.45
# 2010-07-06  121.879997   2506700.0    13.97   77154700.0       12.81
#
#             PCRFYvolume  TSLAclose  TSLAvolume
# Date
# 2010-06-29     467600.0  23.889999  18766300.0
# 2010-06-30     201000.0  23.830000  17187100.0
# 2010-07-01     342500.0  21.959999   8218800.0
# 2010-07-02     157800.0  19.200001   5139800.0
# 2010-07-06     247400.0  16.110001   6866900.0

# %%
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 1805 entries, 2010-06-29 to 2017-08-28
# Data columns (total 18 columns):
# ABBclose       1805 non-null float64
# ABBvolume      1805 non-null float64
# ASYSclose      1805 non-null float64
# ASYSvolume     1805 non-null float64
# CCGIclose      1805 non-null float64
# CCGIvolume     1805 non-null float64
# CENXclose      1805 non-null float64
# CENXvolume     1805 non-null float64
# CMIclose       1805 non-null float64
# CMIvolume      1805 non-null float64
# FSLRclose      1805 non-null float64
# FSLRvolume     1805 non-null float64
# GEclose        1805 non-null float64
# GEvolume       1805 non-null float64
# PCRFYclose     1805 non-null float64
# PCRFYvolume    1805 non-null float64
# TSLAclose      1805 non-null float64
# TSLAvolume     1805 non-null float64
# dtypes: float64(18)
# memory usage: 267.9 KB
